# %% [markdown]
# Note: Check the checkpoints at: https://drive.google.com/drive/u/0/folders/1G8vKjcj3CKgdLIEinw9kNPHbLylZgy7c

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sat May 18 15:35:11 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0              46W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# Connect to Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Preparation**

# %%
path = "/content/drive/MyDrive/MODEL TRAINING/GRAD THESIS"

# %%
import pickle
import pandas as pd
df = pd.read_csv(path + "/train.csv")
df = df.dropna()

# %%
data_train = df.review.to_list()
label_train = df.label.to_list()

# %%
# !pip install --upgrade keras-bert
# !pip install -q keras-rectified-adam
# Out:
# Collecting keras-bert
#   Downloading keras-bert-0.89.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-bert) (1.25.2)
# Collecting keras-transformer==0.40.0 (from keras-bert)
#   Downloading keras-transformer-0.40.0.tar.gz (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-pos-embd==0.13.0 (from keras-transformer==0.40.0->keras-bert)
#   Downloading keras-pos-embd-0.13.0.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-multi-head==0.29.0 (from keras-transformer==0.40.0->keras-bert)
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-layer-normalization==0.16.0 (from keras-transformer==0.40.0->keras-bert)
#   Downloading keras-layer-normalization-0.16.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-position-wise-feed-forward==0.8.0 (from keras-transformer==0.40.0->keras-bert)
#   Downloading keras-position-wise-feed-forward-0.8.0.tar.gz (4.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-embed-sim==0.10.0 (from keras-transformer==0.40.0->keras-bert)
#   Downloading keras-embed-sim-0.10.0.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-self-attention==0.51.0 (from keras-multi-head==0.29.0->keras-transformer==0.40.0->keras-bert)
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: keras-bert, keras-transformer, keras-embed-sim, keras-layer-normalization, keras-multi-head, keras-pos-embd, keras-position-wise-feed-forward, keras-self-attention
#   Building wheel for keras-bert (setup.py) ... done
#   Created wheel for keras-bert: filename=keras_bert-0.89.0-py3-none-any.whl size=33500 sha256=fa8baea8e654b7b00d098d1a56868ecd406ac02c2ee43c97bf16179dfdb25b7a
#   Stored in directory: /root/.cache/pip/wheels/89/0c/04/646b6fdf6375911b42c8d540a8a3fda8d5d77634e5dcbe7b26
#   Building wheel for keras-transformer (setup.py) ... done
#   Created wheel for keras-transformer: filename=keras_transformer-0.40.0-py3-none-any.whl size=12286 sha256=8cbc4dc6d73ac0650f12384d21914abeb69fb39198fc3c7156380dc0fc592deb
#   Stored in directory: /root/.cache/pip/wheels/f2/cb/22/75a0ad376129177f7c95c0d91331a18f5368fd657f4035ba7c
#   Building wheel for keras-embed-sim (setup.py) ... done
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.10.0-py3-none-any.whl size=3944 sha256=6a99e4a34f22ab4b9fc50e9542cae2fc5f3edb57efa65f1e4bd5bdc2eb22b956
#   Stored in directory: /root/.cache/pip/wheels/82/32/c7/fd35d0d1b840a6c7cbd4343f808d10d0f7b87d271a4dbe796f
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.16.0-py3-none-any.whl size=4654 sha256=9d3d1e8a539622753a545e4a98770c678fc8372c5f546dfac00713a6997b1746
#   Stored in directory: /root/.cache/pip/wheels/ed/3a/4b/21db23c0cc56c4b219616e181f258eb7c57d36cc5d056fae9a
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14976 sha256=79ff14556c27d62b9c9bc3a23d0d829b7602148538ca960866267c5cbe289c1c
#   Stored in directory: /root/.cache/pip/wheels/cb/23/4b/06d7ae21714f70fcc25b48f972cc8e5e7f4b6b764a038b509d
#   Building wheel for keras-pos-embd (setup.py) ... done
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.13.0-py3-none-any.whl size=6945 sha256=fd98bad81f9d0bba74bdec38c4bfa0b754be3d24215b8c1bdd2317cc5bf21bc1
#   Stored in directory: /root/.cache/pip/wheels/78/07/1b/b1ca47b6ac338554b75c8f52c54e6a2bfbe1b07d79579979a4
#   Building wheel for keras-position-wise-feed-forward (setup.py) ... done
#   Created wheel for keras-position-wise-feed-forward: filename=keras_position_wise_feed_forward-0.8.0-py3-none-any.whl size=4969 sha256=0754407a5689bd0c6e1719da914bd1d70c5995de16f3850bfcb1fbf230d7f756
#   Stored in directory: /root/.cache/pip/wheels/c1/6a/04/d1706a53b23b2cb5f9a0a76269bf87925daa1bca09eac01b21
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18894 sha256=a05c16586449188f174f8953dd21cfc48e29bdbb55dc647c07e2c8456195789c
#   Stored in directory: /root/.cache/pip/wheels/b8/f7/24/607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
# Successfully built keras-bert keras-transformer keras-embed-sim keras-layer-normalization keras-multi-head keras-pos-embd keras-position-wise-feed-forward keras-self-attention
# Installing collected packages: keras-self-attention, keras-position-wise-feed-forward, keras-pos-embd, keras-layer-normalization, keras-embed-sim, keras-multi-head, keras-transformer, keras-bert
# Successfully installed keras-bert-0.89.0 keras-embed-sim-0.10.0 keras-layer-normalization-0.16.0 keras-multi-head-0.29.0 keras-pos-embd-0.13.0 keras-position-wise-feed-forward-0.8.0 keras-self-attention-0.51.0 keras-transformer-0.40.0
#   Preparing metadata (setup.py) ... done
#   Building wheel for keras-rectified-adam (setup.py) ... done

# %%
# !pip install tensorflow==2.15.0
# Out:
# Requirement already satisfied: tensorflow==2.15.0 in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.64.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)

# %%
# !pip install keras==2.15.0
# Out:
# Requirement already satisfied: keras==2.15.0 in /usr/local/lib/python3.10/dist-packages (2.15.0)

# %%
import codecs
import tensorflow.keras as tf
import keras
import os
from keras import backend as K
from keras_bert import load_trained_model_from_checkpoint
import numpy as np

# %%
SEQ_LEN = 256
BATCH_SIZE = 16
EPOCHS = 10
LR = 2e-5

# %%
# !wget -q https://storage.googleapis.com/bert_models/2018_11_23/multi_cased_L-12_H-768_A-12.zip
# !unzip -o multi_cased_L-12_H-768_A-12.zip
# Out:
# Archive:  multi_cased_L-12_H-768_A-12.zip
#    creating: multi_cased_L-12_H-768_A-12/
#   inflating: multi_cased_L-12_H-768_A-12/bert_model.ckpt.meta
#   inflating: multi_cased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
#   inflating: multi_cased_L-12_H-768_A-12/vocab.txt
#   inflating: multi_cased_L-12_H-768_A-12/bert_model.ckpt.index
#   inflating: multi_cased_L-12_H-768_A-12/bert_config.json

# %%
pretrained_path = 'multi_cased_L-12_H-768_A-12'
config_path = os.path.join(pretrained_path, 'bert_config.json')
checkpoint_path = os.path.join(pretrained_path, 'bert_model.ckpt')
vocab_path = os.path.join(pretrained_path, 'vocab.txt')

# %%
model = load_trained_model_from_checkpoint(
    config_path,
    checkpoint_path,
    seq_len=SEQ_LEN,
    output_layer_num=4,
    trainable=True
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer GlorotNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(

# %%
token_dict = {}
with codecs.open(vocab_path, 'rb','utf-8') as reader:
    for line in reader:
        token = line.strip()
        token_dict[token] = len(token_dict)

# %%
from keras_bert import Tokenizer
tokenizer = Tokenizer(token_dict,cased=True)

# %%
from keras_bert.layers import Extract
from keras.regularizers import l1
from keras.layers import LSTM,SpatialDropout1D
from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import Dense, LSTM, SpatialDropout1D
# !pip install --upgrade keras_radam
# Out:
# Collecting keras_radam
#   Downloading keras-radam-0.15.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras_radam) (1.25.2)
# Requirement already satisfied: Keras in /usr/local/lib/python3.10/dist-packages (from keras_radam) (2.15.0)
# Building wheels for collected packages: keras_radam
#   Building wheel for keras_radam (setup.py) ... done
#   Created wheel for keras_radam: filename=keras_radam-0.15.0-py3-none-any.whl size=14668 sha256=49919f82a54f1372c7dcbb973c8823a894d7a06ae58e04ef7bc5f88b026209d1
#   Stored in directory: /root/.cache/pip/wheels/e6/e0/44/3d07c185de530721a196a5368d48f6256233337e2c90159f24
# Successfully built keras_radam
# Installing collected packages: keras_radam
# Successfully installed keras_radam-0.15.0

# %%
inputs = model.inputs[:2]
bert_out = SpatialDropout1D(0.2)(model.output)
l_lstm = LSTM(256)(bert_out)
newout = keras.layers.Dense(768,activation='relu')(l_lstm)
preds = keras.layers.Dense(units=1, activation='sigmoid')(newout)
model = keras.models.Model(inputs, preds)
model.compile(
  Adam(learning_rate=LR),
  loss='binary_crossentropy',
  metrics=['accuracy'],
)

# Ensure the model summary
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  Input-Token (InputLayer)    [(None, 256)]                0         []
#
#  Input-Segment (InputLayer)  [(None, 256)]                0         []
#
#  Embedding-Token (TokenEmbe  [(None, 256, 768),           9181209   ['Input-Token[0][0]']
#  dding)                       (119547, 768)]              6
#
#  Embedding-Segment (Embeddi  (None, 256, 768)             1536      ['Input-Segment[0][0]']
#  ng)
#
#  Embedding-Token-Segment (A  (None, 256, 768)             0         ['Embedding-Token[0][0]',
#  dd)                                                                 'Embedding-Segment[0][0]']
#
#  Embedding-Position (Positi  (None, 256, 768)             196608    ['Embedding-Token-Segment[0][0
#  onEmbedding)                                                       ]']
#
#  Embedding-Dropout (Dropout  (None, 256, 768)             0         ['Embedding-Position[0][0]']
#  )
#
#  Embedding-Norm (LayerNorma  (None, 256, 768)             1536      ['Embedding-Dropout[0][0]']
#  lization)
#
#  Encoder-1-MultiHeadSelfAtt  (None, 256, 768)             2362368   ['Embedding-Norm[0][0]']
#  ention (MultiHeadAttention
#  )
#
#  Encoder-1-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-1-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-1-MultiHeadSelfAtt  (None, 256, 768)             0         ['Embedding-Norm[0][0]',
#  ention-Add (Add)                                                    'Encoder-1-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-1-MultiHeadSelfAtt  (None, 256, 768)             1536      ['Encoder-1-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-1-FeedForward (Fee  (None, 256, 768)             4722432   ['Encoder-1-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-1-FeedForward-Drop  (None, 256, 768)             0         ['Encoder-1-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-1-FeedForward-Add   (None, 256, 768)             0         ['Encoder-1-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-1-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-1-FeedForward-Norm  (None, 256, 768)             1536      ['Encoder-1-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-2-MultiHeadSelfAtt  (None, 256, 768)             2362368   ['Encoder-1-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Encoder-2-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-2-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-2-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-1-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Encoder-2-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-2-MultiHeadSelfAtt  (None, 256, 768)             1536      ['Encoder-2-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-2-FeedForward (Fee  (None, 256, 768)             4722432   ['Encoder-2-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-2-FeedForward-Drop  (None, 256, 768)             0         ['Encoder-2-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-2-FeedForward-Add   (None, 256, 768)             0         ['Encoder-2-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-2-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-2-FeedForward-Norm  (None, 256, 768)             1536      ['Encoder-2-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-3-MultiHeadSelfAtt  (None, 256, 768)             2362368   ['Encoder-2-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Encoder-3-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-3-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-3-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-2-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Encoder-3-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-3-MultiHeadSelfAtt  (None, 256, 768)             1536      ['Encoder-3-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-3-FeedForward (Fee  (None, 256, 768)             4722432   ['Encoder-3-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-3-FeedForward-Drop  (None, 256, 768)             0         ['Encoder-3-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-3-FeedForward-Add   (None, 256, 768)             0         ['Encoder-3-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-3-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-3-FeedForward-Norm  (None, 256, 768)             1536      ['Encoder-3-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-4-MultiHeadSelfAtt  (None, 256, 768)             2362368   ['Encoder-3-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Encoder-4-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-4-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-4-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-3-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Encoder-4-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-4-MultiHeadSelfAtt  (None, 256, 768)             1536      ['Encoder-4-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-4-FeedForward (Fee  (None, 256, 768)             4722432   ['Encoder-4-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-4-FeedForward-Drop  (None, 256, 768)             0         ['Encoder-4-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-4-FeedForward-Add   (None, 256, 768)             0         ['Encoder-4-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-4-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-4-FeedForward-Norm  (None, 256, 768)             1536      ['Encoder-4-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-5-MultiHeadSelfAtt  (None, 256, 768)             2362368   ['Encoder-4-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Encoder-5-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-5-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-5-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-4-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Encoder-5-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-5-MultiHeadSelfAtt  (None, 256, 768)             1536      ['Encoder-5-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-5-FeedForward (Fee  (None, 256, 768)             4722432   ['Encoder-5-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-5-FeedForward-Drop  (None, 256, 768)             0         ['Encoder-5-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-5-FeedForward-Add   (None, 256, 768)             0         ['Encoder-5-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-5-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-5-FeedForward-Norm  (None, 256, 768)             1536      ['Encoder-5-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-6-MultiHeadSelfAtt  (None, 256, 768)             2362368   ['Encoder-5-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Encoder-6-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-6-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-6-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-5-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Encoder-6-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-6-MultiHeadSelfAtt  (None, 256, 768)             1536      ['Encoder-6-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-6-FeedForward (Fee  (None, 256, 768)             4722432   ['Encoder-6-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-6-FeedForward-Drop  (None, 256, 768)             0         ['Encoder-6-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-6-FeedForward-Add   (None, 256, 768)             0         ['Encoder-6-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-6-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-6-FeedForward-Norm  (None, 256, 768)             1536      ['Encoder-6-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-7-MultiHeadSelfAtt  (None, 256, 768)             2362368   ['Encoder-6-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Encoder-7-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-7-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-7-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-6-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Encoder-7-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-7-MultiHeadSelfAtt  (None, 256, 768)             1536      ['Encoder-7-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-7-FeedForward (Fee  (None, 256, 768)             4722432   ['Encoder-7-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-7-FeedForward-Drop  (None, 256, 768)             0         ['Encoder-7-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-7-FeedForward-Add   (None, 256, 768)             0         ['Encoder-7-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-7-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-7-FeedForward-Norm  (None, 256, 768)             1536      ['Encoder-7-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-8-MultiHeadSelfAtt  (None, 256, 768)             2362368   ['Encoder-7-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Encoder-8-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-8-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-8-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-7-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Encoder-8-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-8-MultiHeadSelfAtt  (None, 256, 768)             1536      ['Encoder-8-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-8-FeedForward (Fee  (None, 256, 768)             4722432   ['Encoder-8-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-8-FeedForward-Drop  (None, 256, 768)             0         ['Encoder-8-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-8-FeedForward-Add   (None, 256, 768)             0         ['Encoder-8-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-8-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-8-FeedForward-Norm  (None, 256, 768)             1536      ['Encoder-8-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-9-MultiHeadSelfAtt  (None, 256, 768)             2362368   ['Encoder-8-FeedForward-Norm[0
#  ention (MultiHeadAttention                                         ][0]']
#  )
#
#  Encoder-9-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-9-MultiHeadSelfAtten
#  ention-Dropout (Dropout)                                           tion[0][0]']
#
#  Encoder-9-MultiHeadSelfAtt  (None, 256, 768)             0         ['Encoder-8-FeedForward-Norm[0
#  ention-Add (Add)                                                   ][0]',
#                                                                      'Encoder-9-MultiHeadSelfAtten
#                                                                     tion-Dropout[0][0]']
#
#  Encoder-9-MultiHeadSelfAtt  (None, 256, 768)             1536      ['Encoder-9-MultiHeadSelfAtten
#  ention-Norm (LayerNormaliz                                         tion-Add[0][0]']
#  ation)
#
#  Encoder-9-FeedForward (Fee  (None, 256, 768)             4722432   ['Encoder-9-MultiHeadSelfAtten
#  dForward)                                                          tion-Norm[0][0]']
#
#  Encoder-9-FeedForward-Drop  (None, 256, 768)             0         ['Encoder-9-FeedForward[0][0]'
#  out (Dropout)                                                      ]
#
#  Encoder-9-FeedForward-Add   (None, 256, 768)             0         ['Encoder-9-MultiHeadSelfAtten
#  (Add)                                                              tion-Norm[0][0]',
#                                                                      'Encoder-9-FeedForward-Dropou
#                                                                     t[0][0]']
#
#  Encoder-9-FeedForward-Norm  (None, 256, 768)             1536      ['Encoder-9-FeedForward-Add[0]
#   (LayerNormalization)                                              [0]']
#
#  Encoder-10-MultiHeadSelfAt  (None, 256, 768)             2362368   ['Encoder-9-FeedForward-Norm[0
#  tention (MultiHeadAttentio                                         ][0]']
#  n)
#
#  Encoder-10-MultiHeadSelfAt  (None, 256, 768)             0         ['Encoder-10-MultiHeadSelfAtte
#  tention-Dropout (Dropout)                                          ntion[0][0]']
#
#  Encoder-10-MultiHeadSelfAt  (None, 256, 768)             0         ['Encoder-9-FeedForward-Norm[0
#  tention-Add (Add)                                                  ][0]',
#                                                                      'Encoder-10-MultiHeadSelfAtte
#                                                                     ntion-Dropout[0][0]']
#
#  Encoder-10-MultiHeadSelfAt  (None, 256, 768)             1536      ['Encoder-10-MultiHeadSelfAtte
#  tention-Norm (LayerNormali                                         ntion-Add[0][0]']
#  zation)
#
#  Encoder-10-FeedForward (Fe  (None, 256, 768)             4722432   ['Encoder-10-MultiHeadSelfAtte
#  edForward)                                                         ntion-Norm[0][0]']
#
#  Encoder-10-FeedForward-Dro  (None, 256, 768)             0         ['Encoder-10-FeedForward[0][0]
#  pout (Dropout)                                                     ']
#
#  Encoder-10-FeedForward-Add  (None, 256, 768)             0         ['Encoder-10-MultiHeadSelfAtte
#   (Add)                                                             ntion-Norm[0][0]',
#                                                                      'Encoder-10-FeedForward-Dropo
#                                                                     ut[0][0]']
#
#  Encoder-10-FeedForward-Nor  (None, 256, 768)             1536      ['Encoder-10-FeedForward-Add[0
#  m (LayerNormalization)                                             ][0]']
#
#  Encoder-11-MultiHeadSelfAt  (None, 256, 768)             2362368   ['Encoder-10-FeedForward-Norm[
#  tention (MultiHeadAttentio                                         0][0]']
#  n)
#
#  Encoder-11-MultiHeadSelfAt  (None, 256, 768)             0         ['Encoder-11-MultiHeadSelfAtte
#  tention-Dropout (Dropout)                                          ntion[0][0]']
#
#  Encoder-11-MultiHeadSelfAt  (None, 256, 768)             0         ['Encoder-10-FeedForward-Norm[
#  tention-Add (Add)                                                  0][0]',
#                                                                      'Encoder-11-MultiHeadSelfAtte
#                                                                     ntion-Dropout[0][0]']
#
#  Encoder-11-MultiHeadSelfAt  (None, 256, 768)             1536      ['Encoder-11-MultiHeadSelfAtte
#  tention-Norm (LayerNormali                                         ntion-Add[0][0]']
#  zation)
#
#  Encoder-11-FeedForward (Fe  (None, 256, 768)             4722432   ['Encoder-11-MultiHeadSelfAtte
#  edForward)                                                         ntion-Norm[0][0]']
#
#  Encoder-11-FeedForward-Dro  (None, 256, 768)             0         ['Encoder-11-FeedForward[0][0]
#  pout (Dropout)                                                     ']
#
#  Encoder-11-FeedForward-Add  (None, 256, 768)             0         ['Encoder-11-MultiHeadSelfAtte
#   (Add)                                                             ntion-Norm[0][0]',
#                                                                      'Encoder-11-FeedForward-Dropo
#                                                                     ut[0][0]']
#
#  Encoder-11-FeedForward-Nor  (None, 256, 768)             1536      ['Encoder-11-FeedForward-Add[0
#  m (LayerNormalization)                                             ][0]']
#
#  Encoder-12-MultiHeadSelfAt  (None, 256, 768)             2362368   ['Encoder-11-FeedForward-Norm[
#  tention (MultiHeadAttentio                                         0][0]']
#  n)
#
#  Encoder-12-MultiHeadSelfAt  (None, 256, 768)             0         ['Encoder-12-MultiHeadSelfAtte
#  tention-Dropout (Dropout)                                          ntion[0][0]']
#
#  Encoder-12-MultiHeadSelfAt  (None, 256, 768)             0         ['Encoder-11-FeedForward-Norm[
#  tention-Add (Add)                                                  0][0]',
#                                                                      'Encoder-12-MultiHeadSelfAtte
#                                                                     ntion-Dropout[0][0]']
#
#  Encoder-12-MultiHeadSelfAt  (None, 256, 768)             1536      ['Encoder-12-MultiHeadSelfAtte
#  tention-Norm (LayerNormali                                         ntion-Add[0][0]']
#  zation)
#
#  Encoder-12-FeedForward (Fe  (None, 256, 768)             4722432   ['Encoder-12-MultiHeadSelfAtte
#  edForward)                                                         ntion-Norm[0][0]']
#
#  Encoder-12-FeedForward-Dro  (None, 256, 768)             0         ['Encoder-12-FeedForward[0][0]
#  pout (Dropout)                                                     ']
#
#  Encoder-12-FeedForward-Add  (None, 256, 768)             0         ['Encoder-12-MultiHeadSelfAtte
#   (Add)                                                             ntion-Norm[0][0]',
#                                                                      'Encoder-12-FeedForward-Dropo
#                                                                     ut[0][0]']
#
#  Encoder-12-FeedForward-Nor  (None, 256, 768)             1536      ['Encoder-12-FeedForward-Add[0
#  m (LayerNormalization)                                             ][0]']
#
#  Encoder-Output (Concatenat  (None, 256, 3072)            0         ['Encoder-9-FeedForward-Norm[0
#  e)                                                                 ][0]',
#                                                                      'Encoder-10-FeedForward-Norm[
#                                                                     0][0]',
#                                                                      'Encoder-11-FeedForward-Norm[
#                                                                     0][0]',
#                                                                      'Encoder-12-FeedForward-Norm[
#                                                                     0][0]']
#
#  spatial_dropout1d (Spatial  (None, 256, 3072)            0         ['Encoder-Output[0][0]']
#  Dropout1D)
#
#  lstm (LSTM)                 (None, 256)                  3408896   ['spatial_dropout1d[0][0]']
#
#  dense (Dense)               (None, 768)                  197376    ['lstm[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    769       ['dense[0][0]']
#
# ==================================================================================================
# Total params: 180673281 (689.21 MB)
# Trainable params: 180673281 (689.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
def load_data(data, sentiments):
    global tokenizer
    indices = []
    for text in data:
      ids, segments = tokenizer.encode(text, max_len=SEQ_LEN)
      indices.append(ids)
    indices = np.array(indices)
    X = {
        'Input-Token': indices,
        'Input-Segment': np.zeros_like(indices)
    }
    return X, np.array(sentiments)

# %%
data_train_,data_valid,label_train_,label_valid = train_test_split(data_train,label_train,test_size=0.2,random_state=48)

# %%
test = pd.read_csv(path + "/test.csv")
test = test.dropna()
data_test = test.review.tolist()
label_test = test.label.tolist()

# %%
X_train,Y_train = load_data(data_train_,label_train_)
X_valid,Y_valid = load_data(data_valid,label_valid)
X_test,Y_test = load_data(data_test,label_test)

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(path + "/256_checkpoint_lstm.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
history = model.fit(X_train, Y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose = 1, validation_data=[X_valid,Y_valid], callbacks=callbacks_list)
# Out:
# Epoch 1/10
# 766/766 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9189
# Epoch 1: val_accuracy improved from -inf to 0.93407, saving model to /content/drive/MyDrive/GRAD THESIS/256_checkpoint_lstm.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 766/766 [==============================] - 260s 275ms/step - loss: 0.2347 - accuracy: 0.9189 - val_loss: 0.1934 - val_accuracy: 0.9341
# Epoch 2/10
# 766/766 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9410
# Epoch 2: val_accuracy improved from 0.93407 to 0.93603, saving model to /content/drive/MyDrive/GRAD THESIS/256_checkpoint_lstm.h5
#
# Epoch 2: val_accuracy improved from 0.93407 to 0.93603, saving model to /content/drive/MyDrive/GRAD THESIS/256_checkpoint_lstm.h5
#
# Epoch 2: val_accuracy improved from 0.93407 to 0.93603, saving model to /content/drive/MyDrive/GRAD THESIS/256_checkpoint_lstm.h5
# 766/766 [==============================] - 215s 281ms/step - loss: 0.1777 - accuracy: 0.9410 - val_loss: 0.1995 - val_accuracy: 0.9360
# 766/766 [==============================] - 215s 281ms/step - loss: 0.1777 - accuracy: 0.9410 - val_loss: 0.1995 - val_accuracy: 0.9360
# 766/766 [==============================] - 215s 281ms/step - loss: 0.1777 - accuracy: 0.9410 - val_loss: 0.1995 - val_accuracy: 0.9360
# Epoch 3/10
#   1/766 [..............................] - ETA: 3:31 - loss: 0.1278 - accuracy: 0.9375Epoch 3/10
#   2/766 [..............................] - ETA: 2:57 - loss: 0.0876 - accuracy: 0.9688Epoch 3/10
# 766/766 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9506
# Epoch 3: val_accuracy did not improve from 0.93603
#
# Epoch 3: val_accuracy did not improve from 0.93603
#
# Epoch 3: val_accuracy did not improve from 0.93603
# 766/766 [==============================] - 192s 251ms/step - loss: 0.1530 - accuracy: 0.9506 - val_loss: 0.2164 - val_accuracy: 0.9324
# Epoch 4/10
# 766/766 [==============================] - 192s 251ms/step - loss: 0.1530 - accuracy: 0.9506 - val_loss: 0.2164 - val_accuracy: 0.9324
# Epoch 4/10
# 766/766 [==============================] - 192s 251ms/step - loss: 0.1530 - accuracy: 0.9506 - val_loss: 0.2164 - val_accuracy: 0.9324
# Epoch 4/10
# 766/766 [==============================] - ETA: 0s - loss: 0.1321 - accuracy: 0.9613
# Epoch 4: val_accuracy did not improve from 0.93603
#
# Epoch 4: val_accuracy did not improve from 0.93603
#
# Epoch 4: val_accuracy did not improve from 0.93603
# 766/766 [==============================] - 191s 250ms/step - loss: 0.1321 - accuracy: 0.9613 - val_loss: 0.2140 - val_accuracy: 0.9275
# Epoch 5/10
# 766/766 [==============================] - 191s 250ms/step - loss: 0.1321 - accuracy: 0.9613 - val_loss: 0.2140 - val_accuracy: 0.9275
# Epoch 5/10
# 766/766 [==============================] - 191s 250ms/step - loss: 0.1321 - accuracy: 0.9613 - val_loss: 0.2140 - val_accuracy: 0.9275
# Epoch 5/10
# 766/766 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9674
# Epoch 5: val_accuracy did not improve from 0.93603
#
# Epoch 5: val_accuracy did not improve from 0.93603
#
# Epoch 5: val_accuracy did not improve from 0.93603
# 766/766 [==============================] - 192s 250ms/step - loss: 0.1157 - accuracy: 0.9674 - val_loss: 0.2511 - val_accuracy: 0.9269
# Epoch 6/10
# 766/766 [==============================] - 192s 250ms/step - loss: 0.1157 - accuracy: 0.9674 - val_loss: 0.2511 - val_accuracy: 0.9269
# Epoch 6/10
# 766/766 [==============================] - 192s 250ms/step - loss: 0.1157 - accuracy: 0.9674 - val_loss: 0.2511 - val_accuracy: 0.9269
# Epoch 6/10
# 766/766 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9741
# Epoch 6: val_accuracy did not improve from 0.93603
#
# Epoch 6: val_accuracy did not improve from 0.93603
#
# Epoch 6: val_accuracy did not improve from 0.93603
# 766/766 [==============================] - 192s 250ms/step - loss: 0.0981 - accuracy: 0.9741 - val_loss: 0.2589 - val_accuracy: 0.9308
# Epoch 7/10
# 766/766 [==============================] - 192s 250ms/step - loss: 0.0981 - accuracy: 0.9741 - val_loss: 0.2589 - val_accuracy: 0.9308
# Epoch 7/10
# 766/766 [==============================] - 192s 250ms/step - loss: 0.0981 - accuracy: 0.9741 - val_loss: 0.2589 - val_accuracy: 0.9308
# Epoch 7/10
# 766/766 [==============================] - ETA: 0s - loss: 0.0876 - accuracy: 0.9778
# Epoch 7: val_accuracy did not improve from 0.93603
#
# Epoch 7: val_accuracy did not improve from 0.93603
#
# Epoch 7: val_accuracy did not improve from 0.93603
# 766/766 [==============================] - 192s 250ms/step - loss: 0.0876 - accuracy: 0.9778 - val_loss: 0.2806 - val_accuracy: 0.9272
# Epoch 8/10
# 766/766 [==============================] - 192s 250ms/step - loss: 0.0876 - accuracy: 0.9778 - val_loss: 0.2806 - val_accuracy: 0.9272
# Epoch 8/10
# 766/766 [==============================] - 192s 250ms/step - loss: 0.0876 - accuracy: 0.9778 - val_loss: 0.2806 - val_accuracy: 0.9272
# Epoch 8/10
# 766/766 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9795
# Epoch 8: val_accuracy did not improve from 0.93603
#
# Epoch 8: val_accuracy did not improve from 0.93603
#
# Epoch 8: val_accuracy did not improve from 0.93603
# 766/766 [==============================] - 191s 250ms/step - loss: 0.0844 - accuracy: 0.9795 - val_loss: 0.2651 - val_accuracy: 0.9295
# Epoch 9/10
# 766/766 [==============================] - 191s 250ms/step - loss: 0.0844 - accuracy: 0.9795 - val_loss: 0.2651 - val_accuracy: 0.9295
# Epoch 9/10
# 766/766 [==============================] - 191s 250ms/step - loss: 0.0844 - accuracy: 0.9795 - val_loss: 0.2651 - val_accuracy: 0.9295
# Epoch 9/10
# 766/766 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9808
# Epoch 9: val_accuracy did not improve from 0.93603
#
# Epoch 9: val_accuracy did not improve from 0.93603
#
# Epoch 9: val_accuracy did not improve from 0.93603
# 766/766 [==============================] - 191s 250ms/step - loss: 0.0774 - accuracy: 0.9808 - val_loss: 0.2971 - val_accuracy: 0.9315
# Epoch 10/10
# 766/766 [==============================] - 191s 250ms/step - loss: 0.0774 - accuracy: 0.9808 - val_loss: 0.2971 - val_accuracy: 0.9315
# Epoch 10/10
# 766/766 [==============================] - 191s 250ms/step - loss: 0.0774 - accuracy: 0.9808 - val_loss: 0.2971 - val_accuracy: 0.9315
# Epoch 10/10
# 766/766 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9787
# Epoch 10: val_accuracy did not improve from 0.93603
#
# Epoch 10: val_accuracy did not improve from 0.93603
#
# Epoch 10: val_accuracy did not improve from 0.93603
# 766/766 [==============================] - 192s 250ms/step - loss: 0.0862 - accuracy: 0.9787 - val_loss: 0.2626 - val_accuracy: 0.9230
# 766/766 [==============================] - 192s 250ms/step - loss: 0.0862 - accuracy: 0.9787 - val_loss: 0.2626 - val_accuracy: 0.9230
# 766/766 [==============================] - 192s 250ms/step - loss: 0.0862 - accuracy: 0.9787 - val_loss: 0.2626 - val_accuracy: 0.9230

# %%
model.load_weights(path + "/256_checkpoint_lstm.h5")

# %%
y_pred = np.round(model.predict(X_test))
# Out:
# 120/120 [==============================] - 22s 139ms/step

# %%
from sklearn.metrics import precision_score,recall_score,f1_score, accuracy_score
print(precision_score(Y_test,y_pred))
print(recall_score(Y_test,y_pred))
print(f1_score(Y_test,y_pred))
print(accuracy_score(Y_test,y_pred))
# Out:
# 0.9302004146510021
# 0.8757319453480806
# 0.9021447721179624
# 0.9237597911227154

# %%
from sklearn.metrics import classification_report
report=classification_report(Y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      2293
#            1       0.93      0.88      0.90      1537
#
#     accuracy                           0.92      3830
#    macro avg       0.93      0.92      0.92      3830
# weighted avg       0.92      0.92      0.92      3830

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import itertools
matplotlib.rcParams.update({'font.size': 16})
labels = [0,1]
cn = confusion_matrix(Y_test,y_pred,labels=labels)

# %%
#@title plot confusion matrix
def plot_confusion_matrix(cm,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True,
                          target_names=None,
                          path_file='1.svg'):

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig(path_file,format='svg')
    plt.show()

# %%
plot_confusion_matrix(cn, title='Confusion Matrix', normalize=False, target_names=labels, path_file=path + "/bert_lstm.svg")

# %% [markdown]
# **Loss Curve**

# %%
def plot_loss_curve(history):
  # Extracting loss and validation loss from training history
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  # Generating range of epochs
  epochs = range(1, len(loss) + 1)

  # Plotting training and validation loss curve
  plt.plot(epochs, loss, 'y', label = 'Training loss')
  plt.plot(epochs, val_loss, 'r', label = 'Validation loss')
  plt.title('Loss Curve')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()

# %%
plot_loss_curve(history)

# %% [markdown]
# **Accuracy Curve**

# %%
def plot_accuracy_curve(history):
  # Extracting accuracy and validation accuracy from training history
  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  # Generating range of epochs
  epochs = range(1, len(accuracy) + 1)

  # Plotting training and validation accuracy curve
  plt.plot(epochs, accuracy, 'y', label = 'Training accuracy')
  plt.plot(epochs, val_accuracy, 'r', label = 'Validation accuracy')
  plt.title('Accuracy Curve')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.show()

# %%
plot_accuracy_curve(history)

# %% [markdown]
# **ROC Curve**

# %%
# Step 1: Make Predictions
y_pred_proba = model.predict(X_test)
# Out:
# 120/120 [==============================] - 17s 138ms/step

# %%
from sklearn.metrics import roc_curve, auc

# Step 2: Compute ROC Curve
fpr, tpr, thresholds = roc_curve(Y_test, y_pred_proba)

# Step 3: Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = %0.2f)' % auc(fpr, tpr))
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
for i in range(100):
  if y_pred[i]!=Y_test[i]:
    print(y_pred[i],Y_test[i])
    print(data_test[i])
# Out:
# [1.] 0
# gui ma nha may positive ko
# [0.] 1
# kg nhan otp bang tin nhan được
# [1.] 0
# cho thêm nh đông đi
# [1.] 0
# xài riết cái app như cqq luôn positive cứ lỗi negative rồi này_nọ miết thôi dẹp nghỉ qua zalo pay xài ok positive hơn nhiều positive
# [1.] 0
# tôi cho một sao tính_năng đi bộ không hoạt_động
# [0.] 1
# negative negative negative
# [1.] 0
# liên_kết tài_khoản ngân_hàng không được positive ad
# [1.] 0
# dạo này momo làm_việc quá kém negative đi rồi đánh_giá negative hơi cao đấy ngày tàn của momo sắp đến rồi sắp tàn rồi rất vui positive
# [1.] 0
# momo hay bi tinh trang không dang nhap được positive co bao tri thi cung phai bao cho nguoi su dung dv biet truoc va fai co thoi gian nao bao tri hoan thanh chu
# [0.] 1
# khó lúc nhận mã
# [0.] 1
# momo dạo nầy lỗi negative nhiều quá cần khắc_phục ngay
